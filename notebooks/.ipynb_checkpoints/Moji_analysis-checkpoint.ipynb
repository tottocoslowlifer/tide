# %% [markdown]
# ### モジュール，データフレームの読み込み

# %%
import datetime

import matplotlib.pyplot as plt

import pandas as pd

# %% [markdown]
# ### データの確認と編集

# %%
df = pd.read_csv("../data/Moji_Tide_2011-2021/csv/9010_2011-2021.csv")
print(df.columns)
# Out:
# Index(['0時の潮高値(cm)', '1時の潮高値(cm)', '2時の潮高値(cm)', '3時の潮高値(cm)', '4時の潮高値(cm)',
#        '5時の潮高値(cm)', '6時の潮高値(cm)', '7時の潮高値(cm)', '8時の潮高値(cm)', '9時の潮高値(cm)',
#        '10時の潮高値(cm)', '11時の潮高値(cm)', '9010(門司の観測値コード)', '20xx年', 'xx月', 'xx日',
#        '1(午前)/2(午後)'],
#       dtype='object')

# %%
df = df.drop("9010(門司の観測値コード)", axis=1)
df
# Out:
#       0時の潮高値(cm)  1時の潮高値(cm)  2時の潮高値(cm)  3時の潮高値(cm)  4時の潮高値(cm)  5時の潮高値(cm)  \
# 0            NaN         NaN         NaN         NaN         NaN         NaN
# 1            NaN         NaN         NaN         NaN         NaN         NaN
# 2            NaN         NaN         NaN         NaN         NaN         NaN
# 3            NaN         NaN         NaN         NaN         NaN         NaN
# 4            NaN         NaN         NaN         NaN         NaN         NaN
# ...          ...         ...         ...         ...         ...         ...
# 8031        84.0       112.0       141.0       160.0       170.0       176.0
# 8032        39.0        50.0        76.0       111.0       145.0       165.0
# 8033        65.0        72.0        96.0       127.0       157.0       177.0
# 8034        20.0        12.0        24.0        57.0       103.0       144.0
# 8035        61.0        47.0        55.0        84.0       124.0       159.0
#
#       6時の潮高値(cm)  7時の潮高値(cm)  8時の潮高値(cm)  9時の潮高値(cm)  10時の潮高値(cm)  \
# 0            NaN         NaN         NaN         NaN          NaN
# 1            NaN         NaN         NaN         NaN          NaN
# 2            NaN         NaN         NaN         NaN          NaN
# 3            NaN         NaN         NaN         NaN          NaN
# 4            NaN         NaN         NaN         NaN          NaN
# ...          ...         ...         ...         ...          ...
# 8031       174.0       160.0       133.0       102.0         71.0
# 8032       168.0       164.0       152.0       128.0         98.0
# 8033       180.0       169.0       148.0       115.0         81.0
# 8034       163.0       167.0       165.0       152.0        123.0
# 8035       177.0       181.0       173.0       146.0        106.0
#
#       11時の潮高値(cm)  20xx年  xx月  xx日  1(午前)/2(午後)
# 0             NaN     11    1    1            1
# 1             NaN     11    1    1            2
# 2             NaN     11    1    2            1
# 3             NaN     11    1    2            2
# 4             NaN     11    1    3            1
# ...           ...    ...  ...  ...          ...
# 8031         47.0     21   12   29            2
# 8032         76.0     21   12   30            1
# 8033         47.0     21   12   30            2
# 8034         89.0     21   12   31            1
# 8035         64.0     21   12   31            2
#
# [8036 rows x 16 columns]

# %% [markdown]
# ### 年月日の一元化

# %%
date_cols = ["20xx年", "xx月", "xx日"]
df["年月日"] = [
    datetime.date(
        2000 + int(df["20xx年"][i]),
        int(df["xx月"][i]),
        int(df["xx日"][i])
    )for i in range(len(df))
]
df = df.drop(date_cols, axis=1)
df
# Out:
#       0時の潮高値(cm)  1時の潮高値(cm)  2時の潮高値(cm)  3時の潮高値(cm)  4時の潮高値(cm)  5時の潮高値(cm)  \
# 0            NaN         NaN         NaN         NaN         NaN         NaN
# 1            NaN         NaN         NaN         NaN         NaN         NaN
# 2            NaN         NaN         NaN         NaN         NaN         NaN
# 3            NaN         NaN         NaN         NaN         NaN         NaN
# 4            NaN         NaN         NaN         NaN         NaN         NaN
# ...          ...         ...         ...         ...         ...         ...
# 8031        84.0       112.0       141.0       160.0       170.0       176.0
# 8032        39.0        50.0        76.0       111.0       145.0       165.0
# 8033        65.0        72.0        96.0       127.0       157.0       177.0
# 8034        20.0        12.0        24.0        57.0       103.0       144.0
# 8035        61.0        47.0        55.0        84.0       124.0       159.0
#
#       6時の潮高値(cm)  7時の潮高値(cm)  8時の潮高値(cm)  9時の潮高値(cm)  10時の潮高値(cm)  \
# 0            NaN         NaN         NaN         NaN          NaN
# 1            NaN         NaN         NaN         NaN          NaN
# 2            NaN         NaN         NaN         NaN          NaN
# 3            NaN         NaN         NaN         NaN          NaN
# 4            NaN         NaN         NaN         NaN          NaN
# ...          ...         ...         ...         ...          ...
# 8031       174.0       160.0       133.0       102.0         71.0
# 8032       168.0       164.0       152.0       128.0         98.0
# 8033       180.0       169.0       148.0       115.0         81.0
# 8034       163.0       167.0       165.0       152.0        123.0
# 8035       177.0       181.0       173.0       146.0        106.0
#
#       11時の潮高値(cm)  1(午前)/2(午後)         年月日
# 0             NaN            1  2011-01-01
# 1             NaN            2  2011-01-01
# 2             NaN            1  2011-01-02
# 3             NaN            2  2011-01-02
# 4             NaN            1  2011-01-03
# ...           ...          ...         ...
# 8031         47.0            2  2021-12-29
# 8032         76.0            1  2021-12-30
# 8033         47.0            2  2021-12-30
# 8034         89.0            1  2021-12-31
# 8035         64.0            2  2021-12-31
#
# [8036 rows x 14 columns]

# %% [markdown]
# ### 全て欠損している日の削除

# %%
date_keys = []
for i in range(len(df)):
    if df["年月日"][i] not in date_keys:
        date_keys.append(df["年月日"][i])

am_cols = [f"{i}時の潮高値(cm)" for i in range(12)]
pm_cols = [f"{i}時の潮高値(cm)" for i in range(12,24)]

#午前のデータと午後のデータに分けたDataFrameを作成
new_df_list = []
for i in range(len(date_keys)):
    tmp = df[df["年月日"] == date_keys[i]].reset_index().drop("index", axis=1)
    am_data = [item for item in tmp[tmp["1(午前)/2(午後)"] == 1][am_cols].values[0]]
    pm_data = [item for item in tmp[tmp["1(午前)/2(午後)"] == 2][am_cols].values[0]]
    new_df_list.append(am_data + pm_data)

#年月日情報のみのDataFrameと,24時間分のデータを集めたDataFrameを結合
time_cols = am_cols + pm_cols
df = pd.concat([pd.DataFrame(date_keys, columns=["年月日"]), pd.DataFrame(new_df_list, columns=time_cols)], axis=1)
df
# Out:
#              年月日  0時の潮高値(cm)  1時の潮高値(cm)  2時の潮高値(cm)  3時の潮高値(cm)  4時の潮高値(cm)  \
# 0     2011-01-01         NaN         NaN         NaN         NaN         NaN
# 1     2011-01-02         NaN         NaN         NaN         NaN         NaN
# 2     2011-01-03         NaN         NaN         NaN         NaN         NaN
# 3     2011-01-04         NaN         NaN         NaN         NaN         NaN
# 4     2011-01-05         NaN         NaN         NaN         NaN         NaN
# ...          ...         ...         ...         ...         ...         ...
# 4013  2021-12-27       127.0       140.0       145.0       139.0       124.0
# 4014  2021-12-28        99.0       122.0       141.0       150.0       146.0
# 4015  2021-12-29        70.0        92.0       121.0       145.0       155.0
# 4016  2021-12-30        39.0        50.0        76.0       111.0       145.0
# 4017  2021-12-31        20.0        12.0        24.0        57.0       103.0
#
#       5時の潮高値(cm)  6時の潮高値(cm)  7時の潮高値(cm)  8時の潮高値(cm)  ...  14時の潮高値(cm)  \
# 0            NaN         NaN         NaN         NaN  ...          NaN
# 1            NaN         NaN         NaN         NaN  ...          NaN
# 2            NaN         NaN         NaN         NaN  ...          NaN
# 3            NaN         NaN         NaN         NaN  ...          NaN
# 4            NaN         NaN         NaN         NaN  ...          NaN
# ...          ...         ...         ...         ...  ...          ...
# 4013       104.0        81.0        58.0        41.0  ...        154.0
# 4014       133.0       114.0        91.0        73.0  ...        148.0
# 4015       154.0       147.0       135.0       113.0  ...        141.0
# 4016       165.0       168.0       164.0       152.0  ...         96.0
# 4017       144.0       163.0       167.0       165.0  ...         55.0
#
#       15時の潮高値(cm)  16時の潮高値(cm)  17時の潮高値(cm)  18時の潮高値(cm)  19時の潮高値(cm)  \
# 0             NaN          NaN          NaN          NaN          NaN
# 1             NaN          NaN          NaN          NaN          NaN
# 2             NaN          NaN          NaN          NaN          NaN
# 3             NaN          NaN          NaN          NaN          NaN
# 4             NaN          NaN          NaN          NaN          NaN
# ...           ...          ...          ...          ...          ...
# 4013        154.0        150.0        140.0        122.0         96.0
# 4014        154.0        158.0        158.0        145.0        122.0
# 4015        160.0        170.0        176.0        174.0        160.0
# 4016        127.0        157.0        177.0        180.0        169.0
# 4017         84.0        124.0        159.0        177.0        181.0
#
#       20時の潮高値(cm)  21時の潮高値(cm)  22時の潮高値(cm)  23時の潮高値(cm)
# 0             NaN          NaN          NaN          NaN
# 1             NaN          NaN          NaN          NaN
# 2             NaN          NaN          NaN          NaN
# 3             NaN          NaN          NaN          NaN
# 4             NaN          NaN          NaN          NaN
# ...           ...          ...          ...          ...
# 4013         73.0         63.0         66.0         78.0
# 4014         96.0         72.0         58.0         58.0
# 4015        133.0        102.0         71.0         47.0
# 4016        148.0        115.0         81.0         47.0
# 4017        173.0        146.0        106.0         64.0
#
# [4018 rows x 25 columns]

# %%
#年月日を除く全てのデータがNaNであるものを削除
date_dropped_df = df.drop("年月日", axis=1)
index = list(date_dropped_df.dropna(how="all").index)

new_df = df.iloc[index].reset_index().drop("index", axis=1)
new_df
# Out:
#              年月日  0時の潮高値(cm)  1時の潮高値(cm)  2時の潮高値(cm)  3時の潮高値(cm)  4時の潮高値(cm)  \
# 0     2011-04-01        85.0        57.0        43.0        53.0        86.0
# 1     2011-04-02       103.0        68.0        44.0        40.0        62.0
# 2     2011-04-03       121.0        80.0        48.0        33.0        42.0
# 3     2011-04-04       142.0        98.0        59.0        35.0        34.0
# 4     2011-04-05       158.0       117.0        74.0        41.0        30.0
# ...          ...         ...         ...         ...         ...         ...
# 3923  2021-12-27       127.0       140.0       145.0       139.0       124.0
# 3924  2021-12-28        99.0       122.0       141.0       150.0       146.0
# 3925  2021-12-29        70.0        92.0       121.0       145.0       155.0
# 3926  2021-12-30        39.0        50.0        76.0       111.0       145.0
# 3927  2021-12-31        20.0        12.0        24.0        57.0       103.0
#
#       5時の潮高値(cm)  6時の潮高値(cm)  7時の潮高値(cm)  8時の潮高値(cm)  ...  14時の潮高値(cm)  \
# 0          127.0       160.0       179.0       187.0  ...         43.0
# 1          105.0       148.0       179.0       194.0  ...         37.0
# 2           78.0       125.0       165.0       189.0  ...         41.0
# 3           59.0       103.0       148.0       180.0  ...         48.0
# 4           46.0        86.0       132.0       169.0  ...         62.0
# ...          ...         ...         ...         ...  ...          ...
# 3923       104.0        81.0        58.0        41.0  ...        154.0
# 3924       133.0       114.0        91.0        73.0  ...        148.0
# 3925       154.0       147.0       135.0       113.0  ...        141.0
# 3926       165.0       168.0       164.0       152.0  ...         96.0
# 3927       144.0       163.0       167.0       165.0  ...         55.0
#
#       15時の潮高値(cm)  16時の潮高値(cm)  17時の潮高値(cm)  18時の潮高値(cm)  19時の潮高値(cm)  \
# 0            47.0         76.0        119.0        157.0        182.0
# 1            27.0         44.0         85.0        133.0        169.0
# 2            21.0         25.0         57.0        107.0        151.0
# 3            17.0          7.0         27.0         73.0        125.0
# 4            25.0          4.0         10.0         47.0        101.0
# ...           ...          ...          ...          ...          ...
# 3923        154.0        150.0        140.0        122.0         96.0
# 3924        154.0        158.0        158.0        145.0        122.0
# 3925        160.0        170.0        176.0        174.0        160.0
# 3926        127.0        157.0        177.0        180.0        169.0
# 3927         84.0        124.0        159.0        177.0        181.0
#
#       20時の潮高値(cm)  21時の潮高値(cm)  22時の潮高値(cm)  23時の潮高値(cm)
# 0           195.0        193.0        175.0        142.0
# 1           190.0        197.0        188.0        160.0
# 2           182.0        198.0        198.0        178.0
# 3           164.0        187.0        195.0        186.0
# 4           147.0        178.0        194.0        194.0
# ...           ...          ...          ...          ...
# 3923         73.0         63.0         66.0         78.0
# 3924         96.0         72.0         58.0         58.0
# 3925        133.0        102.0         71.0         47.0
# 3926        148.0        115.0         81.0         47.0
# 3927        173.0        146.0        106.0         64.0
#
# [3928 rows x 25 columns]

# %% [markdown]
# ### フルにデータが使える期間の抽出

# %%
start = new_df[new_df["年月日"] == datetime.date(2015, 1, 1)].index[0]
end = new_df[new_df["年月日"] == datetime.date(2017, 1, 1)].index[0]

print(new_df["年月日"][start])
print(new_df["年月日"][end - 1])

full_df = new_df.iloc[start:end].reset_index().drop("index", axis=1)
full_df
# Out:
# 2015-01-01
# 2016-12-31
#             年月日  0時の潮高値(cm)  1時の潮高値(cm)  2時の潮高値(cm)  3時の潮高値(cm)  4時の潮高値(cm)  \
# 0    2015-01-01        45.0        49.0        72.0       107.0       145.0
# 1    2015-01-02        42.0        27.0        36.0        68.0       112.0
# 2    2015-01-03        51.0        19.0         9.0        26.0        66.0
# 3    2015-01-04        86.0        46.0        21.0        20.0        46.0
# 4    2015-01-05       118.0        70.0        31.0        12.0        21.0
# ..          ...         ...         ...         ...         ...         ...
# 726  2016-12-27        97.0        68.0        57.0        69.0        99.0
# 727  2016-12-28        94.0        58.0        30.0        25.0        47.0
# 728  2016-12-29       110.0        69.0        33.0        14.0        25.0
# 729  2016-12-30       133.0        88.0        46.0        13.0         3.0
# 730  2016-12-31       162.0       116.0        71.0        32.0         8.0
#
#      5時の潮高値(cm)  6時の潮高値(cm)  7時の潮高値(cm)  8時の潮高値(cm)  ...  14時の潮高値(cm)  \
# 0         173.0       185.0       180.0       165.0  ...         99.0
# 1         152.0       178.0       188.0       186.0  ...         83.0
# 2         113.0       151.0       176.0       188.0  ...         78.0
# 3          90.0       136.0       173.0       195.0  ...         83.0
# 4          57.0       106.0       152.0       185.0  ...         89.0
# ..          ...         ...         ...         ...  ...          ...
# 726       141.0       176.0       195.0       203.0  ...         83.0
# 727        91.0       142.0       177.0       193.0  ...         77.0
# 728        64.0       119.0       164.0       189.0  ...         90.0
# 729        27.0        79.0       136.0       175.0  ...        107.0
# 730        14.0        53.0       110.0       160.0  ...        128.0
#
#      15時の潮高値(cm)  16時の潮高値(cm)  17時の潮高値(cm)  18時の潮高値(cm)  19時の潮高値(cm)  \
# 0          124.0        153.0        176.0        188.0        185.0
# 1          103.0        135.0        168.0        191.0        200.0
# 2           87.0        114.0        150.0        182.0        203.0
# 3           77.0         95.0        129.0        169.0        201.0
# 4           69.0         73.0        101.0        141.0        179.0
# ..           ...          ...          ...          ...          ...
# 726         84.0        107.0        141.0        180.0        211.0
# 727         69.0         87.0        125.0        170.0        201.0
# 728         68.0         68.0         94.0        139.0        182.0
# 729         73.0         60.0         76.0        117.0        164.0
# 730         89.0         64.0         65.0         93.0        139.0
#
#      20時の潮高値(cm)  21時の潮高値(cm)  22時の潮高値(cm)  23時の潮高値(cm)
# 0          170.0        144.0        110.0         74.0
# 1          192.0        168.0        134.0         92.0
# 2          208.0        196.0        169.0        130.0
# 3          218.0        217.0        198.0        163.0
# 4          207.0        219.0        212.0        188.0
# ..           ...          ...          ...          ...
# 726        220.0        204.0        171.0        132.0
# 727        213.0        212.0        193.0        155.0
# 728        206.0        215.0        206.0        176.0
# 729        197.0        212.0        214.0        199.0
# 730        184.0        210.0        217.0        210.0
#
# [731 rows x 25 columns]

# %% [markdown]
# ### 1日の中の変位の可視化

# %%
x = list(range(1,25))
fig, ax = plt.subplots(5,7, figsize=(15,10))

for i in range(5):
    for j in range(7):
        cnt = 7*i+j

        ax[i, j].plot(x,full_df.iloc[cnt,x])
        ax[i, j].set_ylim(-50,300)
        ax[i, j].set_title(str(full_df["年月日"][cnt]))
 
plt.suptitle("Daily Tide Level Change", fontsize=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# 冒頭35日分のデータを見ると、いずれの日においても極大値と極小値が1日に2回ずつ訪れていると予想できる。また、毎日約1時間ずつ、波が遅れていく。

# %% [markdown]
# ### 2年間の潮位の変化の傾向分析

# %%
full_df["最大値"] = full_df.drop("年月日", axis=1).max(axis=1)
full_df["最小値"] = full_df.drop("年月日", axis=1).min(axis=1)

full_df[["最大値", "最小値"]]
# Out:
#        最大値   最小値
# 0    188.0  45.0
# 1    200.0  27.0
# 2    208.0   9.0
# 3    218.0  20.0
# 4    219.0  12.0
# ..     ...   ...
# 726  220.0  57.0
# 727  213.0  25.0
# 728  215.0  14.0
# 729  214.0   3.0
# 730  217.0   8.0
#
# [731 rows x 2 columns]

# %%
fig = plt.figure(figsize=(7,3))

plt.scatter(x=full_df["年月日"], y=full_df["最大値"])
plt.title("Maximum Tide Level Change")
plt.xlabel("Date")
plt.ylabel("Daily Maximum Tide Level")

plt.show()

# %% [markdown]
# 2015〜2016の2年間の、日毎の最大潮位の推移。どちらの年でも、潮位は8月から10月にかけて高く、2月から3月にかけて低くなっていることが分かる。

# %%
fig = plt.figure(figsize=(7,3))

plt.scatter(x=full_df["年月日"], y=full_df["最小値"])
plt.title("Minimum Tide Level Change")
plt.xlabel("Date")
plt.ylabel("Daily Minimum Tide Level")

plt.show()

# %% [markdown]
# 最小値についてみても大体同じ.
